# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroMartinez128/Actividad-3.-Practica-de-Inicio-de-sesi-n-Pedro-Martinez-0093/blob/main/Actividad_3_Practica_de_Inicio_de_sesi%C3%B3n_Pedro_Martinez_0093.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Pedro Martinez

# %%
while True:
    print("1.Registrate")
    print("2.inicia sesion")
    print("3.Salir")

    opcion = int(input("Selecciona una opcion: "))

    if opcion == 1:
        print("Para registrarte nececitas una cuenta porfavor ingresa un nombre y contraseña :")
        Name = input("ingresa tu nombre: ")
        Password = input("ingresa tu Password: ")
        print("Has sido registrado")
    elif opcion == 2:
        print("Para iniciar sesion pon un nombre y una contraseña")
        Name = input("Ingrasa el nombre de una cuenta ya existente")
        Password = input("Ingresa la contraceña correcta")
        print("Has iniciado sesion correctamente")
    elif opcion == 3:
        print("Gracias por usar el programa")
        print("programa realizado por Pedro Martinez NL = 38 2-H")
        break
    else:
        print("Opcion invalida")
        break
# Out:
# 1.Registrate
# 2.inicia sesion
# 3.Salir
# Selecciona una opcion: 1
# Para registrarte nececitas una cuenta porfavor ingresa un nombre y contraseña :
# ingresa tu nombre: Pedro Martinez
# ingresa tu Password: 123
# Has sido registrado
# 1.Registrate
# 2.inicia sesion
# 3.Salir
# Selecciona una opcion: 2
# Para iniciar sesion pon un nombre y una contraseña
# Ingrasa el nombre de una cuenta ya existentePedro Martinez
# Ingresa la contraceña correcta123
# Has iniciado sesion correctamente
# 1.Registrate
# 2.inicia sesion
# 3.Salir
# Selecciona una opcion: 3
# Gracias por usar el programa
# programa realizado por Pedro Martinez NL = 38 2-H
